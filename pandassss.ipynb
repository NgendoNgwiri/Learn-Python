# %%
import numpy as np
import pandas as pd
#converting tuples to a series
grades = (12,34,56,35,68,36,57,89,23)
grades_series = pd.Series(grades)
details_dict = {'Name': 'Ngendo','Age':'24','Weight':'61','gender':'Female'}
details_series = pd.Series(details_dict)
print(grades_series)
print("---------------------------------------")
print(details_series)
# Out:
# 0    12
# 1    34
# 2    56
# 3    35
# 4    68
# 5    36
# 6    57
# 7    89
# 8    23
# dtype: int64
# ---------------------------------------
# Name      Ngendo
# Age           24
# Weight        61
# gender    Female
# dtype: object

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('ign.csv',delimiter = ',')
print (df)
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# 5               5         Good
# 6               6        Awful
# 7               7      Amazing
# 8               8        Awful
# 9               9         Good
# 10             10         Good
# 11             11         Good
# 12             12         Good
# 13             13      Amazing
# 14             14      Amazing
# 15             15         Okay
# 16             16         Okay
# 17             17        Great
# 18             18     Mediocre
# 19             19         Good
# 20             20         Good
# 21             21         Good
# 22             22         Good
# 23             23         Good
# 24             24      Amazing
# 25             25         Good
# 26             26      Amazing
# 27             27         Good
# 28             28        Great
# ...

# %%
print(df.head())
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
print(df.tail())
# Out:
#        Unnamed: 0 score_phrase                                    title  \
# 18620       18620         Good                Tokyo Mirage Sessions #FE
# 18621       18621      Amazing        LEGO Star Wars: The Force Awakens
# 18622       18622     Mediocre  Star Ocean: Integrity and Faithlessness
# 18623       18623  Masterpiece                                   Inside
# 18624       18624  Masterpiece                                   Inside
#
#                                                      url       platform  \
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...          Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...  PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681  PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435       Xbox One
# 18624                 /games/inside-playdead/pc-20055740             PC
#
#        score              genre editors_choice  release_year  release_month  \
# ...

# %%
print(df.sample(8))
# Out:
#        Unnamed: 0 score_phrase                                  title  \
# 3605         3605        Great            Disciples II: Dark Prophecy
# 3980         3980         Good            Commandos 2: Men of Courage
# 2805         2805         Okay          Rugrats in Paris -- The Movie
# 18412       18412         Okay                             Punch Club
# 2575         2575         Good                     Dynasty Warriors 2
# 12603       12603      Amazing  Resident Evil 5 (Collector's Edition)
# 10854       10854         Good      Tom Clancy's Rainbow Six: Vegas 2
# 13674       13674         Good                          Touchmaster 3
#
#                                                      url       platform  \
# 3605                        /games/disciples-ii/pc-14275             PC
# 3980                        /games/commandos-2/ps2-15746  PlayStation 2
# 2805          /games/rugrats-in-paris-the-movie/ps-14623    PlayStation
# ...

# %%
print(df[['title','platform']])
# Out:
#                                                    title          platform
# 0                                LittleBigPlanet PS Vita  PlayStation Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...  PlayStation Vita
# 2                                   Splice: Tree of Life              iPad
# 3                                                 NHL 13          Xbox 360
# 4                                                 NHL 13     PlayStation 3
# 5                              Total War Battles: Shogun         Macintosh
# 6                                    Double Dragon: Neon          Xbox 360
# 7                                           Guild Wars 2                PC
# 8                                    Double Dragon: Neon     PlayStation 3
# 9                              Total War Battles: Shogun                PC
# 10                               Tekken Tag Tournament 2     PlayStation 3
# ...

# %%
df = pd.read_csv('pandas_tutorial_read (1).csv',delimiter = ';' ,names = ['My_date_time','event','country','user_id','source','topic'])
print(df)
# Out:
#              My_date_time event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
print (df[['country','user_id']])
# Out:
#         country     user_id
# 0     country_7  2458151261
# 1     country_7  2458151262
# 2     country_7  2458151263
# 3     country_7  2458151264
# 4     country_8  2458151265
# 5     country_6  2458151266
# 6     country_2  2458151267
# 7     country_6  2458151268
# 8     country_7  2458151269
# 9     country_5  2458151270
# 10    country_5  2458151271
# 11    country_7  2458151272
# 12    country_5  2458151273
# 13    country_2  2458151274
# 14    country_7  2458151275
# 15    country_7  2458151276
# 16    country_8  2458151277
# 17    country_2  2458151278
# 18    country_4  2458151279
# 19    country_2  2458151280
# 20    country_2  2458151281
# 21    country_7  2458151282
# 22    country_2  2458151283
# 23    country_2  2458151284
# 24    country_7  2458151285
# 25    country_2  2458151286
# 26    country_5  2458151287
# 27    country_2  2458151288
# 28    country_2  2458151289
# 29    country_7  2458151290
# ...         ...         ...
# 1765  country_2  2458153026
# ...

# %%
print(df[pdf.source == 'AdWords'])
# Out:
#              My_date_time event    country     user_id   source          topic
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 22    2018-01-01 00:17:15  read  country_2  2458151283  AdWords         Europe
# 25    2018-01-01 00:18:55  read  country_2  2458151286  AdWords  North America
# 36    2018-01-01 00:30:31  read  country_6  2458151297  AdWords           Asia
# 37    2018-01-01 00:31:24  read  country_7  2458151298  AdWords         Europe
# 45    2018-01-01 00:37:35  read  country_8  2458151306  AdWords           Asia
# 47    2018-01-01 00:39:05  read  country_5  2458151308  AdWords         Europe
# ...

# %%
df.to_csv('new_data.csv',sep ='\t')
